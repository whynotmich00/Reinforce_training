# %%
import jax
import jax.numpy as jnp

# %%
func = lambda x: x**2

jit_func = jax.jit(func)

# %%
from pprint import pprint

pprint(jit_func.lower(10.0).as_text())
# Out:
# ('module @jit__lambda_ attributes {mhlo.num_partitions = 1 : i32, '
#  'mhlo.num_replicas = 1 : i32} {\n'
#  '  func.func public @main(%arg0: tensor<f32>) -> (tensor<f32> '
#  '{jax.result_info = ""}) {\n'
#  '    %0 = stablehlo.multiply %arg0, %arg0 : tensor<f32>\n'
#  '    return %0 : tensor<f32>\n'
#  '  }\n'
#  '}\n')

# %%
jit_grad_func = jax.jit(jax.grad(func))

pprint(jit_grad_func.lower(10.0).as_text())
# Out:
# ('module @jit__lambda_ attributes {mhlo.num_partitions = 1 : i32, '
#  'mhlo.num_replicas = 1 : i32} {\n'
#  '  func.func public @main(%arg0: tensor<f32>) -> (tensor<f32> '
#  '{jax.result_info = ""}) {\n'
#  '    %cst = stablehlo.constant dense<2.000000e+00> : tensor<f32>\n'
#  '    %0 = stablehlo.multiply %cst, %arg0 : tensor<f32>\n'
#  '    %cst_0 = stablehlo.constant dense<1.000000e+00> : tensor<f32>\n'
#  '    %1 = stablehlo.multiply %cst_0, %0 : tensor<f32>\n'
#  '    return %1 : tensor<f32>\n'
#  '  }\n'
#  '}\n')

# %%
from flax import nnx

class MLP(nnx.Module):
    def __init__(self, rngs, output=10):
        self.dense_0 = nnx.Linear(in_features=1000, out_features=output, rngs=rngs)
        self.dense_1 = nnx.Linear(in_features=1000, out_features=output, rngs=rngs)
        self.dense_2 = nnx.Linear(in_features=1000, out_features=output, rngs=rngs)
    
    def __call__(self, x):
        x_0 = nnx.relu(self.dense_0(x))
        x_1 = nnx.relu(self.dense_1(x))
        x_2 = nnx.relu(self.dense_2(x))
        
        return x_0 + x_1 + x_2


rngs = nnx.Rngs(0)

mlp = MLP(rngs)

inputs = jnp.ones((10, 1000))

mlp(inputs).shape
# Out:
# (10, 10)

# %%
class Linear:
    def __init__(self, in_features, out_features, num_policies, seed=0):
        
        self.weights = jax.random.uniform(jax.random.key(seed), shape=(num_policies, in_features, out_features)) # policies
        self.bias = jax.random.uniform(jax.random.key(seed), shape=(num_policies, 1, out_features))
    
    def __call__(self, x):
        dot_prod = jax.vmap(jnp.dot, in_axes=(None, 0))(x, self.weights)
        return jax.nn.relu(dot_prod) + self.bias

in_features = 1000
batch_size = 64

linear_jax = Linear(in_features=in_features, out_features=10, num_policies=10)

inputs = jax.random.normal(jax.random.key(0), shape=(batch_size, in_features)) # (64, 1000)
outputs = linear_jax(inputs)
outputs = jnp.argmax(outputs, axis=-1, keepdims=True)

# %%
labels = jnp.array([1,] * batch_size)[:, None] # (batch_size, 1)
labels.shape
# Out:
# (64, 1)

# %%
from jax.experimental import checkify
from functools import partial

@partial(jax.jit)
def policy_evaluation(outputs, labels):
    def _returns(outputs, labels):
        return jnp.sum(outputs == labels[None, :, None], axis=(-1, -2))
    
    # should have l (batch_size, 1) and out (num_policies, batch_size, 1)
    # jax.experimental.checkify.check(labels.shape == outputs.shape[1:], f"wrong shapes {labels.shape=} {outputs.shape[1:]}")
    # outputs = model(inputs)
    outputs = jnp.argmax(outputs, axis=-1, keepdims=True)
    return _returns(outputs, labels)


def policy_improvement():
    # take the best
    pass


# jit_policy_eval = jax.jit(checkify.checkify(policy_evalutation))
# jit_policy_eval(outputs, labels)[1].shape

# %%
# best_policy = jnp.argmax(jit_policy_eval(outputs, labels)[1])
# worst_policy = jnp.argmin(jit_policy_eval(outputs, labels)[1])

# print("accuracy of the best policy")
# print(jit_policy_eval(outputs, labels)[1][best_policy] / batch_size)

# print("accuracy of the worst policy")
# print(jit_policy_eval(outputs, labels)[1][worst_policy] / batch_size)

# %%
# class MLP_jax:
#     def __init__(self, in_features, out_features, seed=0):
#         self.dense_0 = Linear(in_features=in_features, out_features=1000, seed=seed)
#         self.dense_1 = Linear(in_features=1000, out_features=1000, seed=seed)
#         self.dense_2 = Linear(in_features=1000, out_features=out_features, seed=seed)
    
#     def __call__(self, x):
#         x = self.dense_0(x)
#         x = jax.nn.relu(x)
#         x = self.dense_1(x)
#         x = jax.nn.relu(x)
#         return self.dense_2(x)

# mlp = MLP_jax(in_features=in_features, out_features=10)

# mlp(inputs).shape

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.data import Dataset, AUTOTUNE

def get_mnsit_dataloaders(batch_size):
    # Load the MNIST dataset
    (x_train, y_train), (x_test, y_test) = mnist.load_data()
    
    # Normalize the images to [0, 1]
    x_train = x_train.astype("float32") / 255.0
    x_test = x_test.astype("float32") / 255.0
    
    x_train = x_train.reshape(x_train.shape[0], -1)
    x_test = x_test.reshape(x_test.shape[0], -1)
    
    train_dataset = Dataset.from_tensor_slices((x_train, y_train)).shuffle(buffer_size=1024).batch(batch_size=batch_size).prefetch(AUTOTUNE)
    test_dataset = Dataset.from_tensor_slices((x_test, y_test)).shuffle(buffer_size=1024).batch(batch_size=batch_size).prefetch(AUTOTUNE)
    
    return train_dataset, test_dataset
# Out:
# 2025-01-20 09:30:05.372698: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1737361805.507647 2109905 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1737361805.545180 2109905 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train.shape
# Out:
# (60000, 28, 28)

# %%
from jax.tree_util import tree_flatten

# %%
from jax.tree_util import tree_map

# @partial(jax.vmap, in_axes=({"w": 0, "b": 0}, None)) # vmap over policies
def dense(params, x):
    return jnp.matmul(x, params["w"]) #+ params["b"][:, None]


def init(in_features, hidden_dim, out_features, num_layers=4):
    shape_in = (in_features, hidden_dim)
    shape_hid = ((hidden_dim, hidden_dim),) * (num_layers - 2)
    shape_out = (hidden_dim, out_features)
    
    shapes = (shape_in, *shape_hid, shape_out)
    params = {f"dense_{layer}": {"w": (), "b": ()} for layer in range(num_layers)}
    
    for shape, layer in zip(shapes, params.values()):
        in_f, out_f = shape
        print(f"{shape=}")
        sigma = 2 / (in_f + out_f)
        layer["w"] = jnp.sqrt(sigma) * jax.random.normal(jax.random.key(0), shape=shape)
        layer["b"] = jnp.sqrt(sigma) * jax.random.normal(jax.random.key(0), shape=shape[slice(0, len(shape), len(shape)-1)])
    
    return params

pars = {"w": jnp.ones((10, 100, 1)), "b": jnp.ones((10, 1))}
inputs = jnp.ones((64, 100))

dense(pars, inputs).shape
# Out:
# (10, 64, 1)

# %%
x = jnp.ones((1, 64, 200))
x1 = jnp.ones((64, 200))
y = jnp.ones((10, 200, 1))
jnp.allclose(jnp.matmul(x, y), jnp.dot(x1, y).transpose(1, 0, 2))
# Out:
# Array(True, dtype=bool)

# %%
x = jnp.ones((64, 200))
y = jnp.ones((1, 200, 1))
z = jnp.ones((10, 1, 200))
f = jnp.matmul(x, y)
jnp.matmul(f, z).shape
# Out:
# (10, 64, 200)

# %%
params = init(in_features=100, hidden_dim=100, out_features=10)

@jax.jit
def forward(params, x):
    last = len(params.keys()) - 1
    for i, param in enumerate(params.values()):
        x = jax.nn.relu(dense(param, x)) if i != last else dense(param, x)
    return x

@jax.jit
def eval_step(params, x, labels):
    outputs = forward(params, x)
    outputs = jnp.argmax(outputs, axis=-1, keepdims=True)
    return jnp.mean(outputs == labels[:, None])

predicted = forward(params, inputs)
predicted.shape
# Out:
# shape=(100, 100)
# shape=(100, 100)
# shape=(100, 100)
# shape=(100, 10)
# (64, 10)

# %%
for i in reversed(params):
    print(params[i]["w"].shape)
# Out:
# (10, 100, 10)
# (10, 100, 100)
# (10, 100, 100)
# (10, 100, 100)

# %%
jnp.var(predicted)
# Out:
# Array(0.19269249, dtype=float32)

# %%
import jax.numpy as jnp
import numpy as np
# from matplotlib.pyplot import matshow
# import matplotlib.pyplt as plt


train_dataset, test_dataset = get_mnsit_dataloaders(batch_size=512)
# initialize network
params = init(in_features=28*28, hidden_dim=100, out_features=10)

for epoch in range(10):
    print(f"{epoch=}")
    
    for param in reversed(params.keys()):
        print(f"{param=}")
        
        mean = 0 if epoch == 0 else params[param]["w"]
        std =  1
        
        for step, (imgs, labs) in enumerate(train_dataset):
            imgs, labs = jnp.array(imgs), jnp.array(labs)
            
            # explore
            num_policies = 1000
            shape_pars = (num_policies,) + params[param]["w"].shape
            
            params[param]["w"] = std * jax.random.normal(jax.random.key(0), shape=shape_pars) + mean
            params[param]["b"] = std * jax.random.normal(jax.random.key(0), shape=shape_pars) + mean
            
            # predict
            outputs = forward(params, imgs)
    #         break
    #     break
    # break
            # evaluate
            policy_returns = policy_evaluation(outputs, labs)
            mean = params[param]["w"][best_policy]
            
            best_policy = jnp.argmax(policy_returns, axis=-1)
            accuracy = jnp.max(policy_returns) / imgs.shape[0]
            
            print(f"For batch {step}")
            print(f"{best_policy=:,d} accuracy {accuracy=:.4f}")
            
            params[param]["w"] = params[param]["w"][best_policy]
            # params[param]["b"] = params[param]["b"][best_policy]
            
            # accuracy = jnp.max(policy_returns) / imgs.shape[0]
            
            # print(f"For batch {step}")
            # print(f"{best_policy=:,d} accuracy {accuracy=:.4f}")
    
    val_accuracy = []
    for step, (imgs, labs) in enumerate(test_dataset):
        imgs, labs = jnp.array(imgs), jnp.array(labs)
        
        val_accuracy.append(eval_step(params, imgs, labs))

    print(f"Validation accuracy: {np.mean(val_accuracy):.2f}")
# Out:
# shape=(784, 100)
# shape=(100, 100)
# shape=(100, 100)
# shape=(100, 10)
# epoch=0
# param='dense_3'
# For batch 0
# best_policy=13 accuracy accuracy=0.1816
# For batch 1
# best_policy=58 accuracy accuracy=0.1484
# For batch 2
# best_policy=58 accuracy accuracy=0.1855
# For batch 3
# best_policy=13 accuracy accuracy=0.2168
# For batch 4
# best_policy=59 accuracy accuracy=0.1953
# For batch 5
# best_policy=79 accuracy accuracy=0.2031
# For batch 6
# best_policy=92 accuracy accuracy=0.2363
# For batch 7
# best_policy=33 accuracy accuracy=0.2285
# For batch 8
# best_policy=91 accuracy accuracy=0.2012
# For batch 9
# best_policy=24 accuracy accuracy=0.1953
# For batch 10
# best_policy=2 accuracy accuracy=0.2051
# For batch 11
# best_policy=27 accuracy accuracy=0.2148
# For batch 12
# best_policy=96 accuracy accuracy=0.2559
# For batch 13
# best_policy=33 accuracy accuracy=0.2422
# For batch 14
# best_policy=3 accuracy accuracy=0.2207
# For batch 15
# best_policy=30 accuracy accuracy=0.2598
# For batch 16
# best_policy=85 accuracy accuracy=0.2402
# For batch 17
# best_policy=26 accuracy accuracy=0.2617
# For batch 18
# best_policy=96 accuracy accuracy=0.2578
# For batch 19
# best_policy=46 accuracy accuracy=0.2578
# For batch 20
# best_policy=28 accuracy accuracy=0.2559
# For batch 21
# best_policy=98 accuracy accuracy=0.2656
# For batch 22
# best_policy=22 accuracy accuracy=0.2852
# For batch 23
# best_policy=10 accuracy accuracy=0.2402
# For batch 24
# best_policy=80 accuracy accuracy=0.2559
# For batch 25
# best_policy=83 accuracy accuracy=0.2305
# For batch 26
# best_policy=58 accuracy accuracy=0.2266
# For batch 27
# best_policy=56 accuracy accuracy=0.2578
# For batch 28
# best_policy=54 accuracy accuracy=0.2363
# For batch 29
# best_policy=54 accuracy accuracy=0.2500
# For batch 30
# best_policy=59 accuracy accuracy=0.3027
# For batch 31
# best_policy=71 accuracy accuracy=0.2383
# For batch 32
# best_policy=82 accuracy accuracy=0.2324
# For batch 33
# best_policy=34 accuracy accuracy=0.2383
# For batch 34
# best_policy=56 accuracy accuracy=0.2656
# For batch 35
# best_policy=56 accuracy accuracy=0.2676
# For batch 36
# best_policy=18 accuracy accuracy=0.2598
# For batch 37
# best_policy=11 accuracy accuracy=0.2500
# For batch 38
# best_policy=30 accuracy accuracy=0.2637
# For batch 39
# best_policy=97 accuracy accuracy=0.2578
# For batch 40
# best_policy=59 accuracy accuracy=0.2754
# For batch 41
# best_policy=96 accuracy accuracy=0.2695
# For batch 42
# best_policy=82 accuracy accuracy=0.2480
# For batch 43
# best_policy=14 accuracy accuracy=0.2852
# For batch 44
# best_policy=52 accuracy accuracy=0.2852
# For batch 45
# best_policy=83 accuracy accuracy=0.2656
# For batch 46
# best_policy=2 accuracy accuracy=0.2852
# For batch 47
# best_policy=44 accuracy accuracy=0.2402
# For batch 48
# best_policy=7 accuracy accuracy=0.2891
# For batch 49
# best_policy=85 accuracy accuracy=0.3105
# For batch 50
# best_policy=45 accuracy accuracy=0.2383
# For batch 51
# best_policy=30 accuracy accuracy=0.3008
# For batch 52
# best_policy=38 accuracy accuracy=0.2930
# For batch 53
# best_policy=92 accuracy accuracy=0.2773
# For batch 54
# best_policy=42 accuracy accuracy=0.2441
# For batch 55
# best_policy=86 accuracy accuracy=0.2930
# For batch 56
# best_policy=91 accuracy accuracy=0.2676
# For batch 57
# best_policy=24 accuracy accuracy=0.2578
# For batch 58
# best_policy=33 accuracy accuracy=0.2852
# For batch 59
# best_policy=79 accuracy accuracy=0.2520
# For batch 60
# best_policy=22 accuracy accuracy=0.2832
# For batch 61
# best_policy=97 accuracy accuracy=0.2402
# For batch 62
# best_policy=24 accuracy accuracy=0.2441
# For batch 63
# best_policy=8 accuracy accuracy=0.2832
# For batch 64
# best_policy=36 accuracy accuracy=0.2715
# For batch 65
# best_policy=2 accuracy accuracy=0.2715
# For batch 66
# best_policy=16 accuracy accuracy=0.2988
# For batch 67
# best_policy=46 accuracy accuracy=0.2949
# For batch 68
# best_policy=66 accuracy accuracy=0.2559
# For batch 69
# best_policy=87 accuracy accuracy=0.2656
# For batch 70
# best_policy=26 accuracy accuracy=0.2676
# For batch 71
# best_policy=26 accuracy accuracy=0.2871
# For batch 72
# best_policy=14 accuracy accuracy=0.2812
# For batch 73
# best_policy=99 accuracy accuracy=0.2969
# For batch 74
# best_policy=3 accuracy accuracy=0.2793
# For batch 75
# best_policy=22 accuracy accuracy=0.2949
# For batch 76
# best_policy=16 accuracy accuracy=0.2715
# For batch 77
# best_policy=81 accuracy accuracy=0.2832
# For batch 78
# best_policy=26 accuracy accuracy=0.2832
# For batch 79
# best_policy=17 accuracy accuracy=0.2676
# For batch 80
# best_policy=7 accuracy accuracy=0.2734
# For batch 81
# best_policy=33 accuracy accuracy=0.3027
# For batch 82
# best_policy=33 accuracy accuracy=0.2676
# For batch 83
# best_policy=1 accuracy accuracy=0.2500
# For batch 84
# best_policy=21 accuracy accuracy=0.2754
# For batch 85
# best_policy=38 accuracy accuracy=0.2617
# For batch 86
# best_policy=32 accuracy accuracy=0.2852
# For batch 87
# best_policy=0 accuracy accuracy=0.2676
# For batch 88
# best_policy=84 accuracy accuracy=0.2812
# For batch 89
# best_policy=11 accuracy accuracy=0.2930
# For batch 90
# best_policy=27 accuracy accuracy=0.2832
# For batch 91
# best_policy=54 accuracy accuracy=0.2793
# For batch 92
# best_policy=54 accuracy accuracy=0.2988
# For batch 93
# best_policy=56 accuracy accuracy=0.2676
# For batch 94
# best_policy=57 accuracy accuracy=0.2637
# For batch 95
# best_policy=97 accuracy accuracy=0.2480
# For batch 96
# best_policy=57 accuracy accuracy=0.2988
# For batch 97
# best_policy=52 accuracy accuracy=0.2676
# For batch 98
# best_policy=90 accuracy accuracy=0.2480
# For batch 99
# best_policy=15 accuracy accuracy=0.2617
# For batch 100
# best_policy=26 accuracy accuracy=0.2773
# For batch 101
# best_policy=33 accuracy accuracy=0.2832
# For batch 102
# best_policy=9 accuracy accuracy=0.2891
# For batch 103
# best_policy=8 accuracy accuracy=0.2734
# For batch 104
# best_policy=27 accuracy accuracy=0.2832
# For batch 105
# best_policy=62 accuracy accuracy=0.3086
# For batch 106
# best_policy=6 accuracy accuracy=0.2832
# For batch 107
# best_policy=17 accuracy accuracy=0.2891
# For batch 108
# best_policy=53 accuracy accuracy=0.2617
# For batch 109
# best_policy=22 accuracy accuracy=0.2559
# For batch 110
# best_policy=29 accuracy accuracy=0.2734
# For batch 111
# best_policy=44 accuracy accuracy=0.2871
# For batch 112
# best_policy=75 accuracy accuracy=0.3262
# For batch 113
# best_policy=4 accuracy accuracy=0.3262
# For batch 114
# best_policy=93 accuracy accuracy=0.2969
# For batch 115
# best_policy=9 accuracy accuracy=0.3105
# For batch 116
# best_policy=72 accuracy accuracy=0.2676
# For batch 117
# best_policy=4 accuracy accuracy=0.3125
# param='dense_2'
# For batch 0
# best_policy=0 accuracy accuracy=0.2852
# For batch 1
# best_policy=73 accuracy accuracy=0.1992
# For batch 2
# best_policy=52 accuracy accuracy=0.2246
# For batch 3
# best_policy=0 accuracy accuracy=0.2500
# For batch 4
# best_policy=83 accuracy accuracy=0.2441
# For batch 5
# best_policy=48 accuracy accuracy=0.2715
# For batch 6
# best_policy=0 accuracy accuracy=0.2441
# For batch 7
# best_policy=5 accuracy accuracy=0.2539
# For batch 8
# best_policy=5 accuracy accuracy=0.2539
# For batch 9
# best_policy=9 accuracy accuracy=0.2715
# For batch 10
# best_policy=65 accuracy accuracy=0.2773
# For batch 11
# best_policy=65 accuracy accuracy=0.2930
# For batch 12
# best_policy=92 accuracy accuracy=0.2852
# For batch 13
# best_policy=65 accuracy accuracy=0.2812
# For batch 14
# best_policy=28 accuracy accuracy=0.2969
# For batch 15
# best_policy=82 accuracy accuracy=0.2891
# For batch 16
# best_policy=15 accuracy accuracy=0.2734
# For batch 17
# best_policy=71 accuracy accuracy=0.2715
# For batch 18
# best_policy=96 accuracy accuracy=0.2617
# For batch 19
# best_policy=89 accuracy accuracy=0.3066
# For batch 20
# best_policy=89 accuracy accuracy=0.3086
# For batch 21
# best_policy=1 accuracy accuracy=0.2930
# For batch 22
# best_policy=80 accuracy accuracy=0.2852
# For batch 23
# best_policy=42 accuracy accuracy=0.2832
# For batch 24
# best_policy=48 accuracy accuracy=0.2637
# For batch 25
# best_policy=45 accuracy accuracy=0.2734
# For batch 26
# best_policy=0 accuracy accuracy=0.2871
# For batch 27
# best_policy=47 accuracy accuracy=0.2832
# For batch 28
# best_policy=22 accuracy accuracy=0.3008
# For batch 29
# best_policy=0 accuracy accuracy=0.2988
# For batch 30
# best_policy=18 accuracy accuracy=0.3145
# For batch 31
# best_policy=57 accuracy accuracy=0.3145
# For batch 32
# best_policy=65 accuracy accuracy=0.2637
# For batch 33
# best_policy=62 accuracy accuracy=0.3047
# For batch 34
# best_policy=88 accuracy accuracy=0.2812
# For batch 35
# best_policy=69 accuracy accuracy=0.3242
# For batch 36
# best_policy=55 accuracy accuracy=0.3340
# For batch 37
# best_policy=46 accuracy accuracy=0.2988
# For batch 38
# best_policy=20 accuracy accuracy=0.3438
# For batch 39
# best_policy=43 accuracy accuracy=0.2969
# For batch 40
# best_policy=9 accuracy accuracy=0.3379
# For batch 41
# best_policy=57 accuracy accuracy=0.3340
# For batch 42
# best_policy=29 accuracy accuracy=0.3066
# For batch 43
# best_policy=29 accuracy accuracy=0.3047
# For batch 44
# best_policy=19 accuracy accuracy=0.3359
# For batch 45
# best_policy=11 accuracy accuracy=0.2812
# For batch 46
# best_policy=37 accuracy accuracy=0.3105
# For batch 47
# best_policy=58 accuracy accuracy=0.2891
# For batch 48
# best_policy=62 accuracy accuracy=0.3672
# For batch 49
# best_policy=27 accuracy accuracy=0.3184
# For batch 50
# best_policy=78 accuracy accuracy=0.3125
# For batch 51
# best_policy=86 accuracy accuracy=0.3242
# For batch 52
# best_policy=80 accuracy accuracy=0.3379
# For batch 53
# best_policy=14 accuracy accuracy=0.3301
# For batch 54
# best_policy=93 accuracy accuracy=0.3242
# For batch 55
# best_policy=16 accuracy accuracy=0.3516
# For batch 56
# best_policy=30 accuracy accuracy=0.2871
# For batch 57
# best_policy=84 accuracy accuracy=0.3457
# For batch 58
# best_policy=17 accuracy accuracy=0.3301
# For batch 59
# best_policy=51 accuracy accuracy=0.3242
# For batch 60
# best_policy=1 accuracy accuracy=0.3379
# For batch 61
# best_policy=71 accuracy accuracy=0.3145
# For batch 62
# best_policy=54 accuracy accuracy=0.3105
# For batch 63
# best_policy=57 accuracy accuracy=0.3457
# For batch 64
# best_policy=33 accuracy accuracy=0.3398
# For batch 65
# best_policy=13 accuracy accuracy=0.3359
# For batch 66
# best_policy=58 accuracy accuracy=0.3086
# For batch 67
# best_policy=73 accuracy accuracy=0.3398
# For batch 68
# best_policy=59 accuracy accuracy=0.2930
# For batch 69
# best_policy=54 accuracy accuracy=0.3379
# For batch 70
# best_policy=99 accuracy accuracy=0.3320
# For batch 71
# best_policy=43 accuracy accuracy=0.3145
# For batch 72
# best_policy=17 accuracy accuracy=0.3398
# For batch 73
# best_policy=94 accuracy accuracy=0.2812
# For batch 74
# best_policy=19 accuracy accuracy=0.3301
# For batch 75
# best_policy=96 accuracy accuracy=0.3105
# For batch 76
# best_policy=38 accuracy accuracy=0.2852
# For batch 77
# best_policy=86 accuracy accuracy=0.2637
# For batch 78
# best_policy=63 accuracy accuracy=0.3027
# For batch 79
# best_policy=81 accuracy accuracy=0.2793
# For batch 80
# best_policy=41 accuracy accuracy=0.2676
# For batch 81
# best_policy=21 accuracy accuracy=0.2988
# For batch 82
# best_policy=40 accuracy accuracy=0.3145
# For batch 83
# best_policy=57 accuracy accuracy=0.2910
# For batch 84
# best_policy=0 accuracy accuracy=0.2773
# For batch 85
# best_policy=26 accuracy accuracy=0.2715
# For batch 86
# best_policy=65 accuracy accuracy=0.3125
# For batch 87
# best_policy=39 accuracy accuracy=0.3340
# For batch 88
# best_policy=0 accuracy accuracy=0.2949
# For batch 89
# best_policy=0 accuracy accuracy=0.3301
# For batch 90
# best_policy=37 accuracy accuracy=0.2852
# For batch 91
# best_policy=18 accuracy accuracy=0.3203
# For batch 92
# best_policy=47 accuracy accuracy=0.3203
# For batch 93
# best_policy=5 accuracy accuracy=0.3574
# For batch 94
# best_policy=96 accuracy accuracy=0.3633
# For batch 95
# best_policy=57 accuracy accuracy=0.2852
# For batch 96
# best_policy=88 accuracy accuracy=0.3613
# For batch 97
# best_policy=34 accuracy accuracy=0.3027
# For batch 98
# best_policy=11 accuracy accuracy=0.2969
# For batch 99
# best_policy=86 accuracy accuracy=0.2988
# For batch 100
# best_policy=75 accuracy accuracy=0.3086
# For batch 101
# best_policy=18 accuracy accuracy=0.2910
# For batch 102
# best_policy=71 accuracy accuracy=0.3027
# For batch 103
# best_policy=71 accuracy accuracy=0.3750
# For batch 104
# best_policy=93 accuracy accuracy=0.3105
# For batch 105
# best_policy=0 accuracy accuracy=0.3086
# For batch 106
# best_policy=0 accuracy accuracy=0.3281
# For batch 107
# best_policy=53 accuracy accuracy=0.3262
# For batch 108
# best_policy=69 accuracy accuracy=0.3047
# For batch 109
# best_policy=0 accuracy accuracy=0.3281
# For batch 110
# best_policy=61 accuracy accuracy=0.3457
# For batch 111
# best_policy=12 accuracy accuracy=0.3008
# For batch 112
# best_policy=36 accuracy accuracy=0.3086
# For batch 113
# best_policy=40 accuracy accuracy=0.3301
# For batch 114
# best_policy=39 accuracy accuracy=0.3379
# For batch 115
# best_policy=38 accuracy accuracy=0.3438
# For batch 116
# best_policy=38 accuracy accuracy=0.3242
# For batch 117
# best_policy=30 accuracy accuracy=0.2917
# param='dense_1'
# For batch 0
# best_policy=0 accuracy accuracy=0.2930
# For batch 1
# best_policy=0 accuracy accuracy=0.1797
# For batch 2
# best_policy=0 accuracy accuracy=0.2637
# For batch 3
# best_policy=0 accuracy accuracy=0.3223
# For batch 4
# best_policy=82 accuracy accuracy=0.3203
# For batch 5
# best_policy=3 accuracy accuracy=0.3730
# For batch 6
# best_policy=3 accuracy accuracy=0.3027
# For batch 7
# best_policy=84 accuracy accuracy=0.3398
# For batch 8
# best_policy=31 accuracy accuracy=0.3145
# For batch 9
# best_policy=2 accuracy accuracy=0.2852
# For batch 10
# best_policy=0 accuracy accuracy=0.3379
# For batch 11
# best_policy=13 accuracy accuracy=0.3066
# For batch 12
# best_policy=0 accuracy accuracy=0.3633
# For batch 13
# best_policy=31 accuracy accuracy=0.3457
# For batch 14
# best_policy=0 accuracy accuracy=0.3184
# For batch 15
# best_policy=71 accuracy accuracy=0.3320
# For batch 16
# best_policy=96 accuracy accuracy=0.3438
# For batch 17
# best_policy=44 accuracy accuracy=0.3633
# For batch 18
# best_policy=35 accuracy accuracy=0.3613
# For batch 19
# best_policy=68 accuracy accuracy=0.3828
# For batch 20
# best_policy=78 accuracy accuracy=0.3398
# For batch 21
# best_policy=78 accuracy accuracy=0.3789
# For batch 22
# best_policy=82 accuracy accuracy=0.3086
# For batch 23
# best_policy=62 accuracy accuracy=0.3789
# For batch 24
# best_policy=90 accuracy accuracy=0.3418
# For batch 25
# best_policy=1 accuracy accuracy=0.3477
# For batch 26
# best_policy=52 accuracy accuracy=0.3496
# For batch 27
# best_policy=68 accuracy accuracy=0.3047
# For batch 28
# best_policy=52 accuracy accuracy=0.3281
# For batch 29
# best_policy=64 accuracy accuracy=0.3320
# For batch 30
# best_policy=64 accuracy accuracy=0.3223
# For batch 31
# best_policy=32 accuracy accuracy=0.3730
# For batch 32
# best_policy=20 accuracy accuracy=0.3711
# For batch 33
# best_policy=66 accuracy accuracy=0.3613
# For batch 34
# best_policy=38 accuracy accuracy=0.3398
# For batch 35
# best_policy=50 accuracy accuracy=0.3477
# For batch 36
# best_policy=39 accuracy accuracy=0.3535
# For batch 37
# best_policy=71 accuracy accuracy=0.3867
# For batch 38
# best_policy=8 accuracy accuracy=0.3496
# For batch 39
# best_policy=78 accuracy accuracy=0.3359
# For batch 40
# best_policy=11 accuracy accuracy=0.3750
# For batch 41
# best_policy=10 accuracy accuracy=0.3574
# For batch 42
# best_policy=13 accuracy accuracy=0.3320
# For batch 43
# best_policy=15 accuracy accuracy=0.3320
# For batch 44
# best_policy=20 accuracy accuracy=0.3281
# For batch 45
# best_policy=79 accuracy accuracy=0.3320
# For batch 46
# best_policy=0 accuracy accuracy=0.3750
# For batch 47
# best_policy=92 accuracy accuracy=0.3613
# For batch 48
# best_policy=50 accuracy accuracy=0.3730
# For batch 49
# best_policy=93 accuracy accuracy=0.4004
# For batch 50
# best_policy=16 accuracy accuracy=0.3594
# For batch 51
# best_policy=73 accuracy accuracy=0.3613
# For batch 52
# best_policy=80 accuracy accuracy=0.3574
# For batch 53
# best_policy=55 accuracy accuracy=0.3613
# For batch 54
# best_policy=69 accuracy accuracy=0.3555
# For batch 55
# best_policy=84 accuracy accuracy=0.3809
# For batch 56
# best_policy=0 accuracy accuracy=0.3652
# For batch 57
# best_policy=99 accuracy accuracy=0.3301
# For batch 58
# best_policy=26 accuracy accuracy=0.3340
# For batch 59
# best_policy=72 accuracy accuracy=0.3613
# For batch 60
# best_policy=7 accuracy accuracy=0.3262
# For batch 61
# best_policy=69 accuracy accuracy=0.3535
# For batch 62
# best_policy=36 accuracy accuracy=0.3594
# For batch 63
# best_policy=94 accuracy accuracy=0.3633
# For batch 64
# best_policy=56 accuracy accuracy=0.3496
# For batch 65
# best_policy=15 accuracy accuracy=0.3262
# For batch 66
# best_policy=68 accuracy accuracy=0.3574
# For batch 67
# best_policy=0 accuracy accuracy=0.3926
# For batch 68
# best_policy=85 accuracy accuracy=0.3691
# For batch 69
# best_policy=90 accuracy accuracy=0.3574
# For batch 70
# best_policy=4 accuracy accuracy=0.3340
# For batch 71
# best_policy=1 accuracy accuracy=0.3477
# For batch 72
# best_policy=96 accuracy accuracy=0.3730
# For batch 73
# best_policy=57 accuracy accuracy=0.3691
# For batch 74
# best_policy=81 accuracy accuracy=0.3672
# For batch 75
# best_policy=17 accuracy accuracy=0.3418
# For batch 76
# best_policy=29 accuracy accuracy=0.3555
# For batch 77
# best_policy=55 accuracy accuracy=0.3438
# For batch 78
# best_policy=12 accuracy accuracy=0.3164
# For batch 79
# best_policy=54 accuracy accuracy=0.2910
# For batch 80
# best_policy=37 accuracy accuracy=0.3418
# For batch 81
# best_policy=93 accuracy accuracy=0.3418
# For batch 82
# best_policy=72 accuracy accuracy=0.3301
# For batch 83
# best_policy=5 accuracy accuracy=0.3164
# For batch 84
# best_policy=0 accuracy accuracy=0.3398
# For batch 85
# best_policy=78 accuracy accuracy=0.3008
# For batch 86
# best_policy=83 accuracy accuracy=0.3242
# For batch 87
# best_policy=32 accuracy accuracy=0.3652
# For batch 88
# best_policy=13 accuracy accuracy=0.3594
# For batch 89
# best_policy=44 accuracy accuracy=0.3398
# For batch 90
# best_policy=31 accuracy accuracy=0.3320
# For batch 91
# best_policy=0 accuracy accuracy=0.3516
# For batch 92
# best_policy=0 accuracy accuracy=0.3613
# For batch 93
# best_policy=0 accuracy accuracy=0.3770
# For batch 94
# best_policy=66 accuracy accuracy=0.3633
# For batch 95
# best_policy=31 accuracy accuracy=0.3398
# For batch 96
# best_policy=42 accuracy accuracy=0.3457
# For batch 97
# best_policy=99 accuracy accuracy=0.3398
# For batch 98
# best_policy=4 accuracy accuracy=0.2871
# For batch 99
# best_policy=23 accuracy accuracy=0.3457
# For batch 100
# best_policy=30 accuracy accuracy=0.3262
# For batch 101
# best_policy=0 accuracy accuracy=0.3555
# For batch 102
# best_policy=12 accuracy accuracy=0.3398
# For batch 103
# best_policy=7 accuracy accuracy=0.3398
# For batch 104
# best_policy=52 accuracy accuracy=0.3887
# For batch 105
# best_policy=17 accuracy accuracy=0.3633
# For batch 106
# best_policy=99 accuracy accuracy=0.3613
# For batch 107
# best_policy=8 accuracy accuracy=0.3789
# For batch 108
# best_policy=17 accuracy accuracy=0.3301
# For batch 109
# best_policy=2 accuracy accuracy=0.3477
# For batch 110
# best_policy=53 accuracy accuracy=0.3848
# For batch 111
# best_policy=9 accuracy accuracy=0.3594
# For batch 112
# best_policy=45 accuracy accuracy=0.3672
# For batch 113
# best_policy=0 accuracy accuracy=0.3613
# For batch 114
# best_policy=2 accuracy accuracy=0.3555
# For batch 115
# best_policy=78 accuracy accuracy=0.3594
# For batch 116
# best_policy=91 accuracy accuracy=0.3418
# For batch 117
# best_policy=56 accuracy accuracy=0.4271
# param='dense_0'
# For batch 0
# best_policy=0 accuracy accuracy=0.3281
# For batch 1
# best_policy=0 accuracy accuracy=0.2090
# For batch 2
# best_policy=0 accuracy accuracy=0.2969
# For batch 3
# best_policy=76 accuracy accuracy=0.3398
# For batch 4
# best_policy=20 accuracy accuracy=0.3359
# For batch 5
# best_policy=8 accuracy accuracy=0.3398
# For batch 6
# best_policy=50 accuracy accuracy=0.3496
# For batch 7
# best_policy=80 accuracy accuracy=0.3789
# For batch 8
# best_policy=64 accuracy accuracy=0.3359
# For batch 9
# best_policy=71 accuracy accuracy=0.3301
# For batch 10
# best_policy=95 accuracy accuracy=0.3926
# For batch 11
# best_policy=53 accuracy accuracy=0.3418
# For batch 12
# best_policy=96 accuracy accuracy=0.3574
# For batch 13
# best_policy=96 accuracy accuracy=0.3340
# For batch 14
# best_policy=94 accuracy accuracy=0.3535
# For batch 15
# best_policy=61 accuracy accuracy=0.3398
# For batch 16
# best_policy=32 accuracy accuracy=0.3477
# For batch 17
# best_policy=0 accuracy accuracy=0.2969
# For batch 18
# best_policy=81 accuracy accuracy=0.4043
# For batch 19
# best_policy=25 accuracy accuracy=0.3770
# For batch 20
# best_policy=98 accuracy accuracy=0.3867
# For batch 21
# best_policy=0 accuracy accuracy=0.3770
# For batch 22
# best_policy=23 accuracy accuracy=0.3672
# For batch 23
# best_policy=19 accuracy accuracy=0.3965
# For batch 24
# best_policy=2 accuracy accuracy=0.3516
# For batch 25
# best_policy=88 accuracy accuracy=0.3457
# For batch 26
# best_policy=3 accuracy accuracy=0.3145
# For batch 27
# best_policy=35 accuracy accuracy=0.3398
# For batch 28
# best_policy=24 accuracy accuracy=0.3555
# For batch 29
# best_policy=43 accuracy accuracy=0.3730
# For batch 30
# best_policy=40 accuracy accuracy=0.3535
# For batch 31
# best_policy=24 accuracy accuracy=0.3652
# For batch 32
# best_policy=29 accuracy accuracy=0.3789
# For batch 33
# best_policy=92 accuracy accuracy=0.3809
# For batch 34
# best_policy=0 accuracy accuracy=0.3496
# For batch 35
# best_policy=76 accuracy accuracy=0.3887
# For batch 36
# best_policy=15 accuracy accuracy=0.4141
# For batch 37
# best_policy=0 accuracy accuracy=0.4434
# For batch 38
# best_policy=8 accuracy accuracy=0.4141
# For batch 39
# best_policy=1 accuracy accuracy=0.4082
# For batch 40
# best_policy=43 accuracy accuracy=0.4395
# For batch 41
# best_policy=74 accuracy accuracy=0.4004
# For batch 42
# best_policy=49 accuracy accuracy=0.3906
# For batch 43
# best_policy=75 accuracy accuracy=0.4219
# For batch 44
# best_policy=30 accuracy accuracy=0.3965
# For batch 45
# best_policy=0 accuracy accuracy=0.3965
# For batch 46
# best_policy=64 accuracy accuracy=0.4160
# For batch 47
# best_policy=64 accuracy accuracy=0.4297
# For batch 48
# best_policy=53 accuracy accuracy=0.4219
# For batch 49
# best_policy=3 accuracy accuracy=0.4082
# For batch 50
# best_policy=4 accuracy accuracy=0.4277
# For batch 51
# best_policy=87 accuracy accuracy=0.4414
# For batch 52
# best_policy=36 accuracy accuracy=0.4395
# For batch 53
# best_policy=24 accuracy accuracy=0.4570
# For batch 54
# best_policy=88 accuracy accuracy=0.4707
# For batch 55
# best_policy=26 accuracy accuracy=0.4199
# For batch 56
# best_policy=0 accuracy accuracy=0.4082
# For batch 57
# best_policy=70 accuracy accuracy=0.3965
# For batch 58
# best_policy=2 accuracy accuracy=0.4062
# For batch 59
# best_policy=85 accuracy accuracy=0.3887
# For batch 60
# best_policy=82 accuracy accuracy=0.4023
# For batch 61
# best_policy=92 accuracy accuracy=0.3984
# For batch 62
# best_policy=98 accuracy accuracy=0.4160
# For batch 63
# best_policy=87 accuracy accuracy=0.4160
# For batch 64
# best_policy=57 accuracy accuracy=0.4316
# For batch 65
# best_policy=0 accuracy accuracy=0.4023
# For batch 66
# best_policy=40 accuracy accuracy=0.3906
# For batch 67
# best_policy=40 accuracy accuracy=0.4238
# For batch 68
# best_policy=64 accuracy accuracy=0.4297
# For batch 69
# best_policy=24 accuracy accuracy=0.4473
# For batch 70
# best_policy=12 accuracy accuracy=0.4180
# For batch 71
# best_policy=89 accuracy accuracy=0.3965
# For batch 72
# best_policy=0 accuracy accuracy=0.3809
# For batch 73
# best_policy=5 accuracy accuracy=0.4199
# For batch 74
# best_policy=39 accuracy accuracy=0.4160
# For batch 75
# best_policy=13 accuracy accuracy=0.4316
# For batch 76
# best_policy=45 accuracy accuracy=0.3770
# For batch 77
# best_policy=39 accuracy accuracy=0.4004
# For batch 78
# best_policy=57 accuracy accuracy=0.3848
# For batch 79
# best_policy=22 accuracy accuracy=0.3828
# For batch 80
# best_policy=45 accuracy accuracy=0.4023
# For batch 81
# best_policy=61 accuracy accuracy=0.3984
# For batch 82
# best_policy=91 accuracy accuracy=0.3438
# For batch 83
# best_policy=54 accuracy accuracy=0.3594
# For batch 84
# best_policy=25 accuracy accuracy=0.3516
# For batch 85
# best_policy=3 accuracy accuracy=0.3672
# For batch 86
# best_policy=58 accuracy accuracy=0.3555
# For batch 87
# best_policy=0 accuracy accuracy=0.3691
# For batch 88
# best_policy=24 accuracy accuracy=0.3730
# For batch 89
# best_policy=56 accuracy accuracy=0.3867
# For batch 90
# best_policy=36 accuracy accuracy=0.4277
# For batch 91
# best_policy=68 accuracy accuracy=0.4141
# For batch 92
# best_policy=19 accuracy accuracy=0.4453
# For batch 93
# best_policy=47 accuracy accuracy=0.4102
# For batch 94
# best_policy=98 accuracy accuracy=0.3613
# For batch 95
# best_policy=8 accuracy accuracy=0.3809
# For batch 96
# best_policy=65 accuracy accuracy=0.3848
# For batch 97
# best_policy=35 accuracy accuracy=0.3965
# For batch 98
# best_policy=88 accuracy accuracy=0.3535
# For batch 99
# best_policy=70 accuracy accuracy=0.3867
# For batch 100
# best_policy=32 accuracy accuracy=0.3750
# For batch 101
# best_policy=3 accuracy accuracy=0.4102
# For batch 102
# best_policy=86 accuracy accuracy=0.4023
# For batch 103
# best_policy=77 accuracy accuracy=0.3926
# For batch 104
# best_policy=18 accuracy accuracy=0.4141
# For batch 105
# best_policy=84 accuracy accuracy=0.3945
# For batch 106
# best_policy=0 accuracy accuracy=0.3828
# For batch 107
# best_policy=68 accuracy accuracy=0.4082
# For batch 108
# best_policy=98 accuracy accuracy=0.4141
# For batch 109
# best_policy=34 accuracy accuracy=0.4512
# For batch 110
# best_policy=42 accuracy accuracy=0.3672
# For batch 111
# best_policy=11 accuracy accuracy=0.3867
# For batch 112
# best_policy=73 accuracy accuracy=0.4023
# For batch 113
# best_policy=83 accuracy accuracy=0.3965
# For batch 114
# best_policy=96 accuracy accuracy=0.3770
# For batch 115
# best_policy=2 accuracy accuracy=0.4102
# For batch 116
# best_policy=97 accuracy accuracy=0.4102
# For batch 117
# best_policy=13 accuracy accuracy=0.5417
# Validation accuracy: 0.37
# epoch=1
# param='dense_3'
# For batch 0
# best_policy=38 accuracy accuracy=0.3828
# For batch 1
# best_policy=43 accuracy accuracy=0.3613
# For batch 2
# best_policy=24 accuracy accuracy=0.3945
# For batch 3
# best_policy=10 accuracy accuracy=0.3867
# For batch 4
# best_policy=89 accuracy accuracy=0.3984
# For batch 5
# best_policy=21 accuracy accuracy=0.3691
# For batch 6
# best_policy=23 accuracy accuracy=0.3828
# For batch 7
# best_policy=20 accuracy accuracy=0.3711
# For batch 8
# best_policy=26 accuracy accuracy=0.4043
# For batch 9
# best_policy=61 accuracy accuracy=0.4160
# For batch 10
# best_policy=23 accuracy accuracy=0.4062
# For batch 11
# best_policy=44 accuracy accuracy=0.4082
# For batch 12
# best_policy=47 accuracy accuracy=0.4277
# For batch 13
# best_policy=52 accuracy accuracy=0.3984
# For batch 14
# best_policy=68 accuracy accuracy=0.4258
# For batch 15
# best_policy=14 accuracy accuracy=0.4062
# For batch 16
# best_policy=10 accuracy accuracy=0.4395
# For batch 17
# best_policy=46 accuracy accuracy=0.4023
# For batch 18
# best_policy=25 accuracy accuracy=0.4453
# For batch 19
# best_policy=16 accuracy accuracy=0.4629
# For batch 20
# best_policy=52 accuracy accuracy=0.4492
# For batch 21
# best_policy=21 accuracy accuracy=0.4375
# For batch 22
# best_policy=23 accuracy accuracy=0.4043
# For batch 23
# best_policy=59 accuracy accuracy=0.4277
# For batch 24
# best_policy=63 accuracy accuracy=0.4180
# For batch 25
# best_policy=83 accuracy accuracy=0.3555
# For batch 26
# best_policy=28 accuracy accuracy=0.3906
# For batch 27
# best_policy=60 accuracy accuracy=0.3711
# For batch 28
# best_policy=29 accuracy accuracy=0.4668
# For batch 29
# best_policy=11 accuracy accuracy=0.4023
# For batch 30
# best_policy=34 accuracy accuracy=0.4004
# For batch 31
# best_policy=13 accuracy accuracy=0.4238
# For batch 32
# best_policy=24 accuracy accuracy=0.3984
# For batch 33
# best_policy=79 accuracy accuracy=0.3984
# For batch 34
# best_policy=44 accuracy accuracy=0.4199
# For batch 35
# best_policy=58 accuracy accuracy=0.4238
# For batch 36
# best_policy=89 accuracy accuracy=0.4512
# For batch 37
# best_policy=55 accuracy accuracy=0.4453
# For batch 38
# best_policy=35 accuracy accuracy=0.4395
# For batch 39
# best_policy=94 accuracy accuracy=0.4219
# For batch 40
# best_policy=42 accuracy accuracy=0.4238
# For batch 41
# best_policy=45 accuracy accuracy=0.4277
# For batch 42
# best_policy=14 accuracy accuracy=0.3984
# For batch 43
# best_policy=61 accuracy accuracy=0.4238
# For batch 44
# best_policy=68 accuracy accuracy=0.3906
# For batch 45
# best_policy=25 accuracy accuracy=0.4199
# For batch 46
# best_policy=0 accuracy accuracy=0.4277
# For batch 47
# best_policy=99 accuracy accuracy=0.4297
# For batch 48
# best_policy=61 accuracy accuracy=0.4277
# For batch 49
# best_policy=21 accuracy accuracy=0.4590
# For batch 50
# best_policy=66 accuracy accuracy=0.4160
# For batch 51
# best_policy=13 accuracy accuracy=0.4746
# For batch 52
# best_policy=76 accuracy accuracy=0.4375
# For batch 53
# best_policy=55 accuracy accuracy=0.4316
# For batch 54
# best_policy=55 accuracy accuracy=0.4453
# For batch 55
# best_policy=44 accuracy accuracy=0.4199
# For batch 56
# best_policy=21 accuracy accuracy=0.4297
# For batch 57
# best_policy=97 accuracy accuracy=0.3926
# For batch 58
# best_policy=31 accuracy accuracy=0.4160
# For batch 59
# best_policy=56 accuracy accuracy=0.4121
# For batch 60
# best_policy=69 accuracy accuracy=0.4277
# For batch 61
# best_policy=61 accuracy accuracy=0.4629
# For batch 62
# best_policy=12 accuracy accuracy=0.3770
# For batch 63
# best_policy=57 accuracy accuracy=0.4355
# For batch 64
# best_policy=25 accuracy accuracy=0.4414
# For batch 65
# best_policy=25 accuracy accuracy=0.4355
# For batch 66
# best_policy=88 accuracy accuracy=0.4355
# For batch 67
# best_policy=58 accuracy accuracy=0.4531
# For batch 68
# best_policy=16 accuracy accuracy=0.4414
# For batch 69
# best_policy=59 accuracy accuracy=0.4238
# For batch 70
# best_policy=13 accuracy accuracy=0.4316
# For batch 71
# best_policy=63 accuracy accuracy=0.4453
# For batch 72
# best_policy=75 accuracy accuracy=0.4434
# For batch 73
# best_policy=12 accuracy accuracy=0.4219
# For batch 74
# best_policy=36 accuracy accuracy=0.4531
# For batch 75
# best_policy=31 accuracy accuracy=0.4805
# For batch 76
# best_policy=45 accuracy accuracy=0.4727
# For batch 77
# best_policy=6 accuracy accuracy=0.4336
# For batch 78
# best_policy=91 accuracy accuracy=0.4727
# For batch 79
# best_policy=30 accuracy accuracy=0.4297
# For batch 80
# best_policy=14 accuracy accuracy=0.4004
# For batch 81
# best_policy=20 accuracy accuracy=0.3984
# For batch 82
# best_policy=87 accuracy accuracy=0.4355
# For batch 83
# best_policy=4 accuracy accuracy=0.4453
# For batch 84
# best_policy=26 accuracy accuracy=0.4629
# For batch 85
# best_policy=67 accuracy accuracy=0.4531
# For batch 86
# best_policy=31 accuracy accuracy=0.4336
# For batch 87
# best_policy=43 accuracy accuracy=0.4219
# For batch 88
# best_policy=27 accuracy accuracy=0.4102
# For batch 89
# best_policy=55 accuracy accuracy=0.4414
# For batch 90
# best_policy=20 accuracy accuracy=0.4766
# For batch 91
# best_policy=50 accuracy accuracy=0.4531
# For batch 92
# best_policy=91 accuracy accuracy=0.4824
# For batch 93
# best_policy=55 accuracy accuracy=0.4785
# For batch 94
# best_policy=67 accuracy accuracy=0.4473
# For batch 95
# best_policy=67 accuracy accuracy=0.4180
# For batch 96
# best_policy=60 accuracy accuracy=0.4375
# For batch 97
# best_policy=97 accuracy accuracy=0.4746
# For batch 98
# best_policy=63 accuracy accuracy=0.4219
# For batch 99
# best_policy=71 accuracy accuracy=0.4453
# For batch 100
# best_policy=72 accuracy accuracy=0.4453
# For batch 101
# best_policy=0 accuracy accuracy=0.4434
# For batch 102
# best_policy=91 accuracy accuracy=0.5195
# For batch 103
# best_policy=26 accuracy accuracy=0.4570
# For batch 104
# best_policy=76 accuracy accuracy=0.4883
# For batch 105
# best_policy=63 accuracy accuracy=0.4668
# For batch 106
# best_policy=35 accuracy accuracy=0.4688
# For batch 107
# best_policy=6 accuracy accuracy=0.4551
# For batch 108
# best_policy=44 accuracy accuracy=0.4805
# For batch 109
# best_policy=18 accuracy accuracy=0.4434
# For batch 110
# best_policy=30 accuracy accuracy=0.5215
# For batch 111
# best_policy=14 accuracy accuracy=0.4512
# For batch 112
# best_policy=2 accuracy accuracy=0.4902
# For batch 113
# best_policy=61 accuracy accuracy=0.4941
# For batch 114
# best_policy=15 accuracy accuracy=0.4727
# For batch 115
# best_policy=85 accuracy accuracy=0.4766
# For batch 116
# best_policy=44 accuracy accuracy=0.4727
# For batch 117
# best_policy=67 accuracy accuracy=0.5000
# param='dense_2'
# For batch 0
# best_policy=51 accuracy accuracy=0.4668
# For batch 1
# best_policy=15 accuracy accuracy=0.4785
# For batch 2
# best_policy=73 accuracy accuracy=0.4727
# For batch 3
# best_policy=23 accuracy accuracy=0.4629
# For batch 4
# best_policy=16 accuracy accuracy=0.4531
# For batch 5
# best_policy=9 accuracy accuracy=0.4863
# For batch 6
# best_policy=73 accuracy accuracy=0.4473
# For batch 7
# best_policy=28 accuracy accuracy=0.4805
# For batch 8
# best_policy=17 accuracy accuracy=0.4551
# For batch 9
# best_policy=53 accuracy accuracy=0.4609
# For batch 10
# best_policy=8 accuracy accuracy=0.5020
# For batch 11
# best_policy=46 accuracy accuracy=0.4844
# For batch 12
# best_policy=84 accuracy accuracy=0.4766
# For batch 13
# best_policy=90 accuracy accuracy=0.5449
# For batch 14
# best_policy=14 accuracy accuracy=0.4961
# For batch 15
# best_policy=28 accuracy accuracy=0.4863
# For batch 16
# best_policy=45 accuracy accuracy=0.4473
# For batch 17
# best_policy=97 accuracy accuracy=0.5020
# For batch 18
# best_policy=93 accuracy accuracy=0.4492
# For batch 19
# best_policy=76 accuracy accuracy=0.5371
# For batch 20
# best_policy=52 accuracy accuracy=0.5078
# For batch 21
# best_policy=50 accuracy accuracy=0.4785
# For batch 22
# best_policy=33 accuracy accuracy=0.5098
# For batch 23
# best_policy=75 accuracy accuracy=0.4355
# For batch 24
# best_policy=19 accuracy accuracy=0.4707
# For batch 25
# best_policy=57 accuracy accuracy=0.4199
# For batch 26
# best_policy=57 accuracy accuracy=0.4316
# For batch 27
# best_policy=65 accuracy accuracy=0.4453
# For batch 28
# best_policy=44 accuracy accuracy=0.4395
# For batch 29
# best_policy=19 accuracy accuracy=0.4434
# For batch 30
# best_policy=96 accuracy accuracy=0.4766
# For batch 31
# best_policy=3 accuracy accuracy=0.4844
# For batch 32
# best_policy=13 accuracy accuracy=0.4375
# For batch 33
# best_policy=52 accuracy accuracy=0.4785
# For batch 34
# best_policy=16 accuracy accuracy=0.4648
# For batch 35
# best_policy=2 accuracy accuracy=0.4902
# For batch 36
# best_policy=47 accuracy accuracy=0.4688
# For batch 37
# best_policy=1 accuracy accuracy=0.4219
# For batch 38
# best_policy=0 accuracy accuracy=0.4766
# For batch 39
# best_policy=20 accuracy accuracy=0.4570
# For batch 40
# best_policy=46 accuracy accuracy=0.4902
# For batch 41
# best_policy=51 accuracy accuracy=0.4824
# For batch 42
# best_policy=43 accuracy accuracy=0.4707
# For batch 43
# best_policy=79 accuracy accuracy=0.4766
# For batch 44
# best_policy=48 accuracy accuracy=0.4707
# For batch 45
# best_policy=11 accuracy accuracy=0.4219
# For batch 46
# best_policy=21 accuracy accuracy=0.4629
# For batch 47
# best_policy=35 accuracy accuracy=0.4492
# For batch 48
# best_policy=81 accuracy accuracy=0.5215
# For batch 49
# best_policy=84 accuracy accuracy=0.4863
# For batch 50
# best_policy=36 accuracy accuracy=0.4453
# For batch 51
# best_policy=65 accuracy accuracy=0.4668
# For batch 52
# best_policy=69 accuracy accuracy=0.4844
# For batch 53
# best_policy=55 accuracy accuracy=0.4531
# For batch 54
# best_policy=33 accuracy accuracy=0.4824
# For batch 55
# best_policy=5 accuracy accuracy=0.4805
# For batch 56
# best_policy=87 accuracy accuracy=0.4355
# For batch 57
# best_policy=17 accuracy accuracy=0.4746
# For batch 58
# best_policy=99 accuracy accuracy=0.4375
# For batch 59
# best_policy=14 accuracy accuracy=0.4727
# For batch 60
# best_policy=59 accuracy accuracy=0.4492
# For batch 61
# best_policy=99 accuracy accuracy=0.4199
# For batch 62
# best_policy=9 accuracy accuracy=0.4336
# For batch 63
# best_policy=80 accuracy accuracy=0.4902
# For batch 64
# best_policy=42 accuracy accuracy=0.4746
# For batch 65
# best_policy=53 accuracy accuracy=0.4844
# For batch 66
# best_policy=2 accuracy accuracy=0.4238
# For batch 67
# best_policy=29 accuracy accuracy=0.4805
# For batch 68
# best_policy=25 accuracy accuracy=0.4785
# For batch 69
# best_policy=50 accuracy accuracy=0.4258
# For batch 70
# best_policy=60 accuracy accuracy=0.4805
# For batch 71
# best_policy=93 accuracy accuracy=0.4492
# For batch 72
# best_policy=54 accuracy accuracy=0.4941
# For batch 73
# best_policy=96 accuracy accuracy=0.4727
# For batch 74
# best_policy=55 accuracy accuracy=0.4707
# For batch 75
# best_policy=73 accuracy accuracy=0.4688
# For batch 76
# best_policy=25 accuracy accuracy=0.4492
# For batch 77
# best_policy=6 accuracy accuracy=0.4844
# For batch 78
# best_policy=53 accuracy accuracy=0.4160
# For batch 79
# best_policy=74 accuracy accuracy=0.4492
# For batch 80
# best_policy=5 accuracy accuracy=0.4609
# For batch 81
# best_policy=2 accuracy accuracy=0.4824
# For batch 82
# best_policy=21 accuracy accuracy=0.4434
# For batch 83
# best_policy=90 accuracy accuracy=0.4629
# For batch 84
# best_policy=24 accuracy accuracy=0.4414
# For batch 85
# best_policy=95 accuracy accuracy=0.4414
# For batch 86
# best_policy=41 accuracy accuracy=0.4629
# For batch 87
# best_policy=23 accuracy accuracy=0.4766
# For batch 88
# best_policy=50 accuracy accuracy=0.4473
# For batch 89
# best_policy=44 accuracy accuracy=0.4707
# For batch 90
# best_policy=46 accuracy accuracy=0.4629
# For batch 91
# best_policy=17 accuracy accuracy=0.4531
# For batch 92
# best_policy=90 accuracy accuracy=0.4668
# For batch 93
# best_policy=9 accuracy accuracy=0.4375
# For batch 94
# best_policy=28 accuracy accuracy=0.4414
# For batch 95
# best_policy=43 accuracy accuracy=0.4297
# For batch 96
# best_policy=98 accuracy accuracy=0.4805
# For batch 97
# best_policy=65 accuracy accuracy=0.4512
# For batch 98
# best_policy=0 accuracy accuracy=0.4238
# For batch 99
# best_policy=55 accuracy accuracy=0.4453
# For batch 100
# best_policy=93 accuracy accuracy=0.4316
# For batch 101
# best_policy=27 accuracy accuracy=0.4570
# For batch 102
# best_policy=21 accuracy accuracy=0.4668
# For batch 103
# best_policy=7 accuracy accuracy=0.4863
# For batch 104
# best_policy=43 accuracy accuracy=0.4805
# For batch 105
# best_policy=65 accuracy accuracy=0.4824
# For batch 106
# best_policy=27 accuracy accuracy=0.4414
# For batch 107
# best_policy=4 accuracy accuracy=0.5000
# For batch 108
# best_policy=4 accuracy accuracy=0.4805
# For batch 109
# best_policy=10 accuracy accuracy=0.4473
# For batch 110
# best_policy=17 accuracy accuracy=0.5078
# For batch 111
# best_policy=30 accuracy accuracy=0.4805
# For batch 112
# best_policy=58 accuracy accuracy=0.4863
# For batch 113
# best_policy=75 accuracy accuracy=0.4648
# For batch 114
# best_policy=43 accuracy accuracy=0.5078
# For batch 115
# best_policy=26 accuracy accuracy=0.4805
# For batch 116
# best_policy=61 accuracy accuracy=0.5000
# For batch 117
# best_policy=7 accuracy accuracy=0.4792
# param='dense_1'
# For batch 0
# best_policy=67 accuracy accuracy=0.4199
# For batch 1
# best_policy=24 accuracy accuracy=0.4688
# For batch 2
# best_policy=33 accuracy accuracy=0.4746
# For batch 3
# best_policy=57 accuracy accuracy=0.4746
# For batch 4
# best_policy=90 accuracy accuracy=0.4648
# For batch 5
# best_policy=38 accuracy accuracy=0.4707
# For batch 6
# best_policy=16 accuracy accuracy=0.4551
# For batch 7
# best_policy=50 accuracy accuracy=0.5098
# For batch 8
# best_policy=48 accuracy accuracy=0.4512
# For batch 9
# best_policy=17 accuracy accuracy=0.4590
# For batch 10
# best_policy=17 accuracy accuracy=0.5098
# For batch 11
# best_policy=11 accuracy accuracy=0.5391
# For batch 12
# best_policy=17 accuracy accuracy=0.4863
# For batch 13
# best_policy=23 accuracy accuracy=0.4766
# For batch 14
# best_policy=54 accuracy accuracy=0.4648
# For batch 15
# best_policy=53 accuracy accuracy=0.4805
# For batch 16
# best_policy=24 accuracy accuracy=0.4883
# For batch 17
# best_policy=29 accuracy accuracy=0.4570
# For batch 18
# best_policy=3 accuracy accuracy=0.5078
# For batch 19
# best_policy=30 accuracy accuracy=0.4980
# For batch 20
# best_policy=38 accuracy accuracy=0.5078
# For batch 21
# best_policy=5 accuracy accuracy=0.5098
# For batch 22
# best_policy=58 accuracy accuracy=0.4824
# For batch 23
# best_policy=85 accuracy accuracy=0.4434
# For batch 24
# best_policy=13 accuracy accuracy=0.4434
# For batch 25
# best_policy=18 accuracy accuracy=0.3848
# For batch 26
# best_policy=31 accuracy accuracy=0.4297
# For batch 27
# best_policy=36 accuracy accuracy=0.4473
# For batch 28
# best_policy=8 accuracy accuracy=0.4238
# For batch 29
# best_policy=86 accuracy accuracy=0.4297
# For batch 30
# best_policy=63 accuracy accuracy=0.4883
# For batch 31
# best_policy=13 accuracy accuracy=0.4453
# For batch 32
# best_policy=16 accuracy accuracy=0.4414
# For batch 33
# best_policy=84 accuracy accuracy=0.4727
# For batch 34
# best_policy=24 accuracy accuracy=0.4668
# For batch 35
# best_policy=11 accuracy accuracy=0.4785
# For batch 36
# best_policy=3 accuracy accuracy=0.4805
# For batch 37
# best_policy=39 accuracy accuracy=0.4824
# For batch 38
# best_policy=25 accuracy accuracy=0.4648
# For batch 39
# best_policy=96 accuracy accuracy=0.4844
# For batch 40
# best_policy=33 accuracy accuracy=0.4609
# For batch 41
# best_policy=96 accuracy accuracy=0.4824
# For batch 42
# best_policy=13 accuracy accuracy=0.4375
# For batch 43
# best_policy=77 accuracy accuracy=0.4902
# For batch 44
# best_policy=52 accuracy accuracy=0.4531
# For batch 45
# best_policy=21 accuracy accuracy=0.4336
# For batch 46
# best_policy=65 accuracy accuracy=0.4570
# For batch 47
# best_policy=89 accuracy accuracy=0.4863
# For batch 48
# best_policy=39 accuracy accuracy=0.4941
# For batch 49
# best_policy=88 accuracy accuracy=0.4531
# For batch 50
# best_policy=62 accuracy accuracy=0.4707
# For batch 51
# best_policy=52 accuracy accuracy=0.4453
# For batch 52
# best_policy=5 accuracy accuracy=0.4531
# For batch 53
# best_policy=13 accuracy accuracy=0.5000
# For batch 54
# best_policy=27 accuracy accuracy=0.4883
# For batch 55
# best_policy=26 accuracy accuracy=0.4609
# For batch 56
# best_policy=90 accuracy accuracy=0.4648
# For batch 57
# best_policy=17 accuracy accuracy=0.4551
# For batch 58
# best_policy=4 accuracy accuracy=0.4395
# For batch 59
# best_policy=37 accuracy accuracy=0.4512
# For batch 60
# best_policy=3 accuracy accuracy=0.4453
# For batch 61
# best_policy=10 accuracy accuracy=0.4609
# For batch 62
# best_policy=42 accuracy accuracy=0.4512
# For batch 63
# best_policy=80 accuracy accuracy=0.4336
# For batch 64
# best_policy=58 accuracy accuracy=0.4980
# For batch 65
# best_policy=36 accuracy accuracy=0.4961
# For batch 66
# best_policy=72 accuracy accuracy=0.4668
# For batch 67
# best_policy=9 accuracy accuracy=0.4492
# For batch 68
# best_policy=54 accuracy accuracy=0.4551
# For batch 69
# best_policy=29 accuracy accuracy=0.4551
# For batch 70
# best_policy=54 accuracy accuracy=0.4590
# For batch 71
# best_policy=78 accuracy accuracy=0.4688
# For batch 72
# best_policy=31 accuracy accuracy=0.4512
# For batch 73
# best_policy=0 accuracy accuracy=0.4609
# For batch 74
# best_policy=10 accuracy accuracy=0.4707
# For batch 75
# best_policy=45 accuracy accuracy=0.4805
# For batch 76
# best_policy=29 accuracy accuracy=0.4277
# For batch 77
# best_policy=23 accuracy accuracy=0.4355
# For batch 78
# best_policy=26 accuracy accuracy=0.4805
# For batch 79
# best_policy=72 accuracy accuracy=0.4531
# For batch 80
# best_policy=38 accuracy accuracy=0.4473
# For batch 81
# best_policy=40 accuracy accuracy=0.4414
# For batch 82
# best_policy=66 accuracy accuracy=0.4395
# For batch 83
# best_policy=42 accuracy accuracy=0.4609
# For batch 84
# best_policy=82 accuracy accuracy=0.4570
# For batch 85
# best_policy=46 accuracy accuracy=0.4434
# For batch 86
# best_policy=67 accuracy accuracy=0.4414
# For batch 87
# best_policy=4 accuracy accuracy=0.4512
# For batch 88
# best_policy=69 accuracy accuracy=0.4531
# For batch 89
# best_policy=36 accuracy accuracy=0.4492
# For batch 90
# best_policy=7 accuracy accuracy=0.4609
# For batch 91
# best_policy=21 accuracy accuracy=0.4883
# For batch 92
# best_policy=13 accuracy accuracy=0.4746
# For batch 93
# best_policy=96 accuracy accuracy=0.4082
# For batch 94
# best_policy=83 accuracy accuracy=0.4570
# For batch 95
# best_policy=43 accuracy accuracy=0.4570
# For batch 96
# best_policy=73 accuracy accuracy=0.4648
# For batch 97
# best_policy=31 accuracy accuracy=0.4453
# For batch 98
# best_policy=58 accuracy accuracy=0.4512
# For batch 99
# best_policy=0 accuracy accuracy=0.4902
# For batch 100
# best_policy=57 accuracy accuracy=0.4648
# For batch 101
# best_policy=37 accuracy accuracy=0.4590
# For batch 102
# best_policy=81 accuracy accuracy=0.4531
# For batch 103
# best_policy=2 accuracy accuracy=0.4395
# For batch 104
# best_policy=89 accuracy accuracy=0.4805
# For batch 105
# best_policy=52 accuracy accuracy=0.4883
# For batch 106
# best_policy=9 accuracy accuracy=0.4766
# For batch 107
# best_policy=43 accuracy accuracy=0.4922
# For batch 108
# best_policy=90 accuracy accuracy=0.4902
# For batch 109
# best_policy=17 accuracy accuracy=0.4922
# For batch 110
# best_policy=35 accuracy accuracy=0.4512
# For batch 111
# best_policy=99 accuracy accuracy=0.4590
# For batch 112
# best_policy=4 accuracy accuracy=0.4668
# For batch 113
# best_policy=21 accuracy accuracy=0.5059
# For batch 114
# best_policy=2 accuracy accuracy=0.4785
# For batch 115
# best_policy=24 accuracy accuracy=0.4648
# For batch 116
# best_policy=78 accuracy accuracy=0.4316
# For batch 117
# best_policy=87 accuracy accuracy=0.5312
# param='dense_0'
# For batch 0
# best_policy=99 accuracy accuracy=0.4922
# For batch 1
# best_policy=31 accuracy accuracy=0.4316
# For batch 2
# best_policy=50 accuracy accuracy=0.4648
# For batch 3
# best_policy=37 accuracy accuracy=0.4453
# For batch 4
# best_policy=53 accuracy accuracy=0.5000
# For batch 5
# best_policy=35 accuracy accuracy=0.4648
# For batch 6
# best_policy=77 accuracy accuracy=0.4355
# For batch 7
# best_policy=8 accuracy accuracy=0.4746
# For batch 8
# best_policy=41 accuracy accuracy=0.4648
# For batch 9
# best_policy=44 accuracy accuracy=0.5098
# For batch 10
# best_policy=93 accuracy accuracy=0.5156
# For batch 11
# best_policy=10 accuracy accuracy=0.4902
# For batch 12
# best_policy=87 accuracy accuracy=0.4941
# For batch 13
# best_policy=55 accuracy accuracy=0.5352
# For batch 14
# best_policy=26 accuracy accuracy=0.4746
# For batch 15
# best_policy=1 accuracy accuracy=0.4629
# For batch 16
# best_policy=20 accuracy accuracy=0.4805
# For batch 17
# best_policy=93 accuracy accuracy=0.4668
# For batch 18
# best_policy=73 accuracy accuracy=0.5039
# For batch 19
# best_policy=16 accuracy accuracy=0.5098
# For batch 20
# best_policy=65 accuracy accuracy=0.4805
# For batch 21
# best_policy=34 accuracy accuracy=0.4902
# For batch 22
# best_policy=90 accuracy accuracy=0.4668
# For batch 23
# best_policy=51 accuracy accuracy=0.4570
# For batch 24
# best_policy=82 accuracy accuracy=0.4473
# For batch 25
# best_policy=45 accuracy accuracy=0.4102
# For batch 26
# best_policy=83 accuracy accuracy=0.4355
# For batch 27
# best_policy=11 accuracy accuracy=0.4297
# For batch 28
# best_policy=88 accuracy accuracy=0.4688
# For batch 29
# best_policy=18 accuracy accuracy=0.4648
# For batch 30
# best_policy=5 accuracy accuracy=0.4492
# For batch 31
# best_policy=12 accuracy accuracy=0.4629
# For batch 32
# best_policy=72 accuracy accuracy=0.4375
# For batch 33
# best_policy=71 accuracy accuracy=0.4160
# For batch 34
# best_policy=65 accuracy accuracy=0.4355
# For batch 35
# best_policy=92 accuracy accuracy=0.4824
# For batch 36
# best_policy=81 accuracy accuracy=0.4668
# For batch 37
# best_policy=36 accuracy accuracy=0.4668
# For batch 38
# best_policy=11 accuracy accuracy=0.4551
# For batch 39
# best_policy=59 accuracy accuracy=0.4727
# For batch 40
# best_policy=88 accuracy accuracy=0.4375
# For batch 41
# best_policy=36 accuracy accuracy=0.5039
# For batch 42
# best_policy=57 accuracy accuracy=0.4766
# For batch 43
# best_policy=7 accuracy accuracy=0.4629
# For batch 44
# best_policy=94 accuracy accuracy=0.4141
# For batch 45
# best_policy=51 accuracy accuracy=0.4824
# For batch 46
# best_policy=75 accuracy accuracy=0.4199
# For batch 47
# best_policy=61 accuracy accuracy=0.4863
# For batch 48
# best_policy=4 accuracy accuracy=0.4785
# For batch 49
# best_policy=56 accuracy accuracy=0.4844
# For batch 50
# best_policy=22 accuracy accuracy=0.4883
# For batch 51
# best_policy=0 accuracy accuracy=0.4590
# For batch 52
# best_policy=23 accuracy accuracy=0.4355
# For batch 53
# best_policy=80 accuracy accuracy=0.4805
# For batch 54
# best_policy=82 accuracy accuracy=0.4648
# For batch 55
# best_policy=12 accuracy accuracy=0.4785
# For batch 56
# best_policy=21 accuracy accuracy=0.4492
# For batch 57
# best_policy=5 accuracy accuracy=0.4199
# For batch 58
# best_policy=76 accuracy accuracy=0.4395
# For batch 59
# best_policy=10 accuracy accuracy=0.4258
# For batch 60
# best_policy=46 accuracy accuracy=0.4355
# For batch 61
# best_policy=33 accuracy accuracy=0.4141
# For batch 62
# best_policy=66 accuracy accuracy=0.4512
# For batch 63
# best_policy=81 accuracy accuracy=0.4570
# For batch 64
# best_policy=77 accuracy accuracy=0.4883
# For batch 65
# best_policy=42 accuracy accuracy=0.4414
# For batch 66
# best_policy=17 accuracy accuracy=0.4707
# For batch 67
# best_policy=5 accuracy accuracy=0.4746
# For batch 68
# best_policy=77 accuracy accuracy=0.4336
# For batch 69
# best_policy=48 accuracy accuracy=0.4434
# For batch 70
# best_policy=0 accuracy accuracy=0.4590
# For batch 71
# best_policy=64 accuracy accuracy=0.4395
# For batch 72
# best_policy=75 accuracy accuracy=0.4121
# For batch 73
# best_policy=98 accuracy accuracy=0.4590
# For batch 74
# best_policy=35 accuracy accuracy=0.4668
# For batch 75
# best_policy=15 accuracy accuracy=0.4395
# For batch 76
# ...
# For batch 53
# best_policy=12 accuracy accuracy=0.4531
# For batch 54
# best_policy=65 accuracy accuracy=0.4688
# For batch 55
# best_policy=29 accuracy accuracy=0.5098
# For batch 56
# best_policy=41 accuracy accuracy=0.4199
# For batch 57
# best_policy=16 accuracy accuracy=0.4609
# For batch 58
# best_policy=87 accuracy accuracy=0.4219
# For batch 59
# best_policy=53 accuracy accuracy=0.3848
# For batch 60
# best_policy=26 accuracy accuracy=0.4258
# For batch 61
# best_policy=58 accuracy accuracy=0.4219
# For batch 62
# best_policy=11 accuracy accuracy=0.4473
# For batch 63
# best_policy=0 accuracy accuracy=0.4355
# For batch 64
# best_policy=33 accuracy accuracy=0.4570
# For batch 65
# best_policy=35 accuracy accuracy=0.4844
# For batch 66
# best_policy=79 accuracy accuracy=0.4727
# For batch 67
# best_policy=10 accuracy accuracy=0.4121
# For batch 68
# best_policy=26 accuracy accuracy=0.4082
# For batch 69
# best_policy=0 accuracy accuracy=0.3926
# For batch 70
# best_policy=35 accuracy accuracy=0.4492
# For batch 71
# best_policy=71 accuracy accuracy=0.4453
# For batch 72
# best_policy=12 accuracy accuracy=0.4395
# For batch 73
# best_policy=27 accuracy accuracy=0.4180
# For batch 74
# best_policy=96 accuracy accuracy=0.4863
# For batch 75
# best_policy=35 accuracy accuracy=0.4902
# For batch 76
# best_policy=7 accuracy accuracy=0.4648
# For batch 77
# best_policy=51 accuracy accuracy=0.4277
# For batch 78
# best_policy=37 accuracy accuracy=0.4551
# For batch 79
# best_policy=8 accuracy accuracy=0.4258
# For batch 80
# best_policy=82 accuracy accuracy=0.4434
# For batch 81
# best_policy=24 accuracy accuracy=0.4336
# For batch 82
# best_policy=12 accuracy accuracy=0.4219
# For batch 83
# best_policy=93 accuracy accuracy=0.4883
# For batch 84
# best_policy=0 accuracy accuracy=0.4434
# For batch 85
# best_policy=46 accuracy accuracy=0.4551
# For batch 86
# best_policy=71 accuracy accuracy=0.4199
# For batch 87
# best_policy=42 accuracy accuracy=0.4512
# For batch 88
# best_policy=18 accuracy accuracy=0.3965
# For batch 89
# best_policy=30 accuracy accuracy=0.4258
# For batch 90
# best_policy=6 accuracy accuracy=0.4336
# For batch 91
# best_policy=30 accuracy accuracy=0.4727
# For batch 92
# best_policy=4 accuracy accuracy=0.4414
# For batch 93
# best_policy=59 accuracy accuracy=0.4336
# For batch 94
# best_policy=54 accuracy accuracy=0.4375
# For batch 95
# best_policy=30 accuracy accuracy=0.4395
# For batch 96
# best_policy=16 accuracy accuracy=0.4727
# For batch 97
# best_policy=4 accuracy accuracy=0.4297
# For batch 98
# best_policy=12 accuracy accuracy=0.4121
# For batch 99
# best_policy=23 accuracy accuracy=0.4746
# For batch 100
# best_policy=33 accuracy accuracy=0.4727
# For batch 101
# best_policy=12 accuracy accuracy=0.4355
# For batch 102
# best_policy=43 accuracy accuracy=0.4453
# For batch 103
# best_policy=18 accuracy accuracy=0.4609
# For batch 104
# best_policy=28 accuracy accuracy=0.4570
# For batch 105
# best_policy=45 accuracy accuracy=0.4395
# For batch 106
# best_policy=0 accuracy accuracy=0.4219
# For batch 107
# best_policy=78 accuracy accuracy=0.4902
# For batch 108
# best_policy=28 accuracy accuracy=0.4570
# For batch 109
# best_policy=44 accuracy accuracy=0.4473
# For batch 110
# best_policy=24 accuracy accuracy=0.4707
# For batch 111
# best_policy=27 accuracy accuracy=0.4629
# For batch 112
# best_policy=72 accuracy accuracy=0.4707
# For batch 113
# best_policy=0 accuracy accuracy=0.4824
# For batch 114
# best_policy=16 accuracy accuracy=0.4297
# For batch 115
# best_policy=13 accuracy accuracy=0.4688
# For batch 116
# best_policy=99 accuracy accuracy=0.4941
# For batch 117
# best_policy=0 accuracy accuracy=0.4167
# param='dense_1'
# For batch 0
# best_policy=2 accuracy accuracy=0.4121
# For batch 1
# best_policy=52 accuracy accuracy=0.4531
# For batch 2
# best_policy=0 accuracy accuracy=0.4824
# For batch 3
# best_policy=37 accuracy accuracy=0.4805
# For batch 4
# best_policy=24 accuracy accuracy=0.4941
# For batch 5
# best_policy=93 accuracy accuracy=0.4336
# For batch 6
# best_policy=41 accuracy accuracy=0.4473
# For batch 7
# best_policy=15 accuracy accuracy=0.4648
# For batch 8
# best_policy=98 accuracy accuracy=0.4355
# For batch 9
# best_policy=20 accuracy accuracy=0.4512
# For batch 10
# best_policy=99 accuracy accuracy=0.4980
# For batch 11
# best_policy=36 accuracy accuracy=0.5117
# For batch 12
# best_policy=33 accuracy accuracy=0.4531
# For batch 13
# best_policy=0 accuracy accuracy=0.4668
# For batch 14
# best_policy=90 accuracy accuracy=0.4434
# For batch 15
# best_policy=9 accuracy accuracy=0.4746
# For batch 16
# best_policy=0 accuracy accuracy=0.4590
# For batch 17
# best_policy=19 accuracy accuracy=0.4707
# For batch 18
# best_policy=5 accuracy accuracy=0.4902
# For batch 19
# best_policy=11 accuracy accuracy=0.4883
# For batch 20
# best_policy=2 accuracy accuracy=0.4688
# For batch 21
# best_policy=72 accuracy accuracy=0.4512
# For batch 22
# best_policy=37 accuracy accuracy=0.4453
# For batch 23
# best_policy=49 accuracy accuracy=0.4512
# For batch 24
# best_policy=10 accuracy accuracy=0.4277
# For batch 25
# best_policy=43 accuracy accuracy=0.4277
# For batch 26
# best_policy=46 accuracy accuracy=0.4023
# For batch 27
# best_policy=21 accuracy accuracy=0.4199
# For batch 28
# best_policy=6 accuracy accuracy=0.4629
# For batch 29
# best_policy=55 accuracy accuracy=0.4785
# For batch 30
# best_policy=26 accuracy accuracy=0.4727
# For batch 31
# best_policy=0 accuracy accuracy=0.4531
# For batch 32
# best_policy=68 accuracy accuracy=0.4180
# For batch 33
# best_policy=58 accuracy accuracy=0.4473
# For batch 34
# best_policy=55 accuracy accuracy=0.4570
# For batch 35
# best_policy=43 accuracy accuracy=0.4629
# For batch 36
# best_policy=98 accuracy accuracy=0.4551
# For batch 37
# best_policy=68 accuracy accuracy=0.4473
# For batch 38
# best_policy=6 accuracy accuracy=0.4531
# For batch 39
# best_policy=4 accuracy accuracy=0.4297
# For batch 40
# best_policy=0 accuracy accuracy=0.4727
# For batch 41
# best_policy=14 accuracy accuracy=0.4375
# For batch 42
# best_policy=13 accuracy accuracy=0.4434
# For batch 43
# best_policy=0 accuracy accuracy=0.4453
# For batch 44
# best_policy=18 accuracy accuracy=0.4570
# For batch 45
# best_policy=77 accuracy accuracy=0.4297
# For batch 46
# best_policy=31 accuracy accuracy=0.4590
# For batch 47
# best_policy=7 accuracy accuracy=0.4824
# For batch 48
# best_policy=1 accuracy accuracy=0.4531
# For batch 49
# best_policy=1 accuracy accuracy=0.4434
# For batch 50
# best_policy=60 accuracy accuracy=0.4609
# For batch 51
# best_policy=1 accuracy accuracy=0.4805
# For batch 52
# best_policy=21 accuracy accuracy=0.4316
# For batch 53
# best_policy=17 accuracy accuracy=0.4590
# For batch 54
# best_policy=8 accuracy accuracy=0.4902
# For batch 55
# best_policy=21 accuracy accuracy=0.4570
# For batch 56
# best_policy=41 accuracy accuracy=0.4824
# For batch 57
# best_policy=9 accuracy accuracy=0.4355
# For batch 58
# best_policy=1 accuracy accuracy=0.4395
# For batch 59
# best_policy=23 accuracy accuracy=0.4141
# For batch 60
# best_policy=16 accuracy accuracy=0.4434
# For batch 61
# best_policy=13 accuracy accuracy=0.4590
# For batch 62
# best_policy=13 accuracy accuracy=0.4648
# For batch 63
# best_policy=24 accuracy accuracy=0.4102
# For batch 64
# best_policy=46 accuracy accuracy=0.4512
# For batch 65
# best_policy=60 accuracy accuracy=0.4668
# For batch 66
# best_policy=31 accuracy accuracy=0.4688
# For batch 67
# best_policy=6 accuracy accuracy=0.4492
# For batch 68
# best_policy=10 accuracy accuracy=0.4414
# For batch 69
# best_policy=2 accuracy accuracy=0.4004
# For batch 70
# best_policy=5 accuracy accuracy=0.4824
# For batch 71
# best_policy=4 accuracy accuracy=0.4551
# For batch 72
# best_policy=44 accuracy accuracy=0.4844
# For batch 73
# best_policy=1 accuracy accuracy=0.4785
# For batch 74
# best_policy=13 accuracy accuracy=0.4492
# For batch 75
# best_policy=18 accuracy accuracy=0.4883
# For batch 76
# best_policy=69 accuracy accuracy=0.4824
# For batch 77
# best_policy=44 accuracy accuracy=0.4805
# For batch 78
# best_policy=58 accuracy accuracy=0.4375
# For batch 79
# best_policy=26 accuracy accuracy=0.4434
# For batch 80
# best_policy=40 accuracy accuracy=0.4180
# For batch 81
# best_policy=6 accuracy accuracy=0.4512
# For batch 82
# best_policy=18 accuracy accuracy=0.4277
# For batch 83
# best_policy=6 accuracy accuracy=0.4688
# For batch 84
# best_policy=10 accuracy accuracy=0.4668
# For batch 85
# best_policy=18 accuracy accuracy=0.4492
# For batch 86
# best_policy=44 accuracy accuracy=0.4434
# For batch 87
# best_policy=15 accuracy accuracy=0.4473
# For batch 88
# best_policy=5 accuracy accuracy=0.4082
# For batch 89
# best_policy=0 accuracy accuracy=0.4297
# For batch 90
# best_policy=58 accuracy accuracy=0.4434
# For batch 91
# best_policy=74 accuracy accuracy=0.4492
# For batch 92
# best_policy=23 accuracy accuracy=0.4609
# For batch 93
# best_policy=12 accuracy accuracy=0.4531
# For batch 94
# best_policy=6 accuracy accuracy=0.4258
# For batch 95
# best_policy=87 accuracy accuracy=0.4180
# For batch 96
# best_policy=90 accuracy accuracy=0.4609
# For batch 97
# best_policy=84 accuracy accuracy=0.4453
# For batch 98
# best_policy=37 accuracy accuracy=0.4727
# For batch 99
# best_policy=78 accuracy accuracy=0.4512
# For batch 100
# best_policy=0 accuracy accuracy=0.4688
# For batch 101
# best_policy=0 accuracy accuracy=0.4512
# For batch 102
# best_policy=90 accuracy accuracy=0.4688
# For batch 103
# best_policy=31 accuracy accuracy=0.4570
# For batch 104
# best_policy=94 accuracy accuracy=0.4492
# For batch 105
# best_policy=58 accuracy accuracy=0.4551
# For batch 106
# best_policy=18 accuracy accuracy=0.4629
# For batch 107
# best_policy=38 accuracy accuracy=0.4707
# For batch 108
# best_policy=39 accuracy accuracy=0.4863
# For batch 109
# best_policy=31 accuracy accuracy=0.4453
# For batch 110
# best_policy=10 accuracy accuracy=0.4473
# For batch 111
# best_policy=99 accuracy accuracy=0.4473
# For batch 112
# best_policy=64 accuracy accuracy=0.4805
# For batch 113
# best_policy=10 accuracy accuracy=0.5254
# For batch 114
# best_policy=2 accuracy accuracy=0.4883
# For batch 115
# best_policy=0 accuracy accuracy=0.4512
# For batch 116
# best_policy=12 accuracy accuracy=0.4531
# For batch 117
# best_policy=57 accuracy accuracy=0.4479
# param='dense_0'
# For batch 0
# best_policy=52 accuracy accuracy=0.4570
# For batch 1
# best_policy=56 accuracy accuracy=0.4414
# For batch 2
# best_policy=9 accuracy accuracy=0.4707
# For batch 3
# best_policy=22 accuracy accuracy=0.4922
# For batch 4
# best_policy=11 accuracy accuracy=0.4805
# For batch 5
# best_policy=87 accuracy accuracy=0.4844
# For batch 6
# best_policy=32 accuracy accuracy=0.4531
# For batch 7
# best_policy=1 accuracy accuracy=0.4043
# For batch 8
# best_policy=15 accuracy accuracy=0.4551
# For batch 9
# best_policy=75 accuracy accuracy=0.4727
# For batch 10
# best_policy=8 accuracy accuracy=0.4941
# For batch 11
# best_policy=38 accuracy accuracy=0.5176
# For batch 12
# best_policy=46 accuracy accuracy=0.4414
# For batch 13
# best_policy=8 accuracy accuracy=0.4395
# For batch 14
# best_policy=59 accuracy accuracy=0.4727
# For batch 15
# best_policy=68 accuracy accuracy=0.4453
# For batch 16
# best_policy=4 accuracy accuracy=0.4512
# For batch 17
# best_policy=1 accuracy accuracy=0.4531
# For batch 18
# best_policy=26 accuracy accuracy=0.4902
# For batch 19
# best_policy=24 accuracy accuracy=0.4922
# For batch 20
# best_policy=93 accuracy accuracy=0.4785
# For batch 21
# best_policy=8 accuracy accuracy=0.4590
# For batch 22
# best_policy=23 accuracy accuracy=0.5059
# For batch 23
# best_policy=24 accuracy accuracy=0.4766
# For batch 24
# best_policy=61 accuracy accuracy=0.4238
# For batch 25
# best_policy=57 accuracy accuracy=0.4277
# For batch 26
# best_policy=36 accuracy accuracy=0.4258
# For batch 27
# best_policy=2 accuracy accuracy=0.4258
# For batch 28
# best_policy=26 accuracy accuracy=0.4570
# For batch 29
# best_policy=59 accuracy accuracy=0.4570
# For batch 30
# best_policy=8 accuracy accuracy=0.4688
# For batch 31
# best_policy=5 accuracy accuracy=0.4492
# For batch 32
# best_policy=0 accuracy accuracy=0.4121
# For batch 33
# best_policy=13 accuracy accuracy=0.4473
# For batch 34
# best_policy=25 accuracy accuracy=0.4492
# For batch 35
# best_policy=2 accuracy accuracy=0.4648
# For batch 36
# best_policy=16 accuracy accuracy=0.4473
# For batch 37
# best_policy=42 accuracy accuracy=0.4512
# For batch 38
# best_policy=6 accuracy accuracy=0.4434
# For batch 39
# best_policy=15 accuracy accuracy=0.4551
# For batch 40
# best_policy=72 accuracy accuracy=0.4512
# For batch 41
# best_policy=28 accuracy accuracy=0.4746
# For batch 42
# best_policy=93 accuracy accuracy=0.4180
# For batch 43
# best_policy=27 accuracy accuracy=0.4727
# For batch 44
# best_policy=9 accuracy accuracy=0.4824
# For batch 45
# best_policy=5 accuracy accuracy=0.4258
# For batch 46
# best_policy=10 accuracy accuracy=0.4492
# For batch 47
# best_policy=83 accuracy accuracy=0.4688
# For batch 48
# best_policy=0 accuracy accuracy=0.4883
# For batch 49
# best_policy=22 accuracy accuracy=0.4473
# For batch 50
# best_policy=96 accuracy accuracy=0.4512
# For batch 51
# best_policy=14 accuracy accuracy=0.4434
# For batch 52
# best_policy=55 accuracy accuracy=0.4609
# For batch 53
# best_policy=86 accuracy accuracy=0.4434
# For batch 54
# best_policy=41 accuracy accuracy=0.4668
# For batch 55
# best_policy=5 accuracy accuracy=0.4492
# For batch 56
# best_policy=16 accuracy accuracy=0.4727
# For batch 57
# best_policy=40 accuracy accuracy=0.4434
# For batch 58
# best_policy=88 accuracy accuracy=0.4121
# For batch 59
# best_policy=61 accuracy accuracy=0.4668
# For batch 60
# best_policy=11 accuracy accuracy=0.3984
# For batch 61
# best_policy=18 accuracy accuracy=0.4297
# For batch 62
# best_policy=5 accuracy accuracy=0.4297
# For batch 63
# best_policy=36 accuracy accuracy=0.4492
# For batch 64
# best_policy=7 accuracy accuracy=0.4512
# For batch 65
# best_policy=90 accuracy accuracy=0.4375
# For batch 66
# best_policy=61 accuracy accuracy=0.4316
# For batch 67
# best_policy=32 accuracy accuracy=0.4395
# For batch 68
# best_policy=5 accuracy accuracy=0.4648
# For batch 69
# best_policy=56 accuracy accuracy=0.4629
# For batch 70
# best_policy=58 accuracy accuracy=0.4297
# For batch 71
# best_policy=80 accuracy accuracy=0.4688
# For batch 72
# best_policy=24 accuracy accuracy=0.4453
# For batch 73
# best_policy=90 accuracy accuracy=0.4414
# For batch 74
# best_policy=0 accuracy accuracy=0.4844
# For batch 75
# best_policy=34 accuracy accuracy=0.4785
# For batch 76
# best_policy=62 accuracy accuracy=0.4883
# For batch 77
# best_policy=19 accuracy accuracy=0.4453
# For batch 78
# best_policy=13 accuracy accuracy=0.4648
# For batch 79
# best_policy=32 accuracy accuracy=0.4258
# For batch 80
# best_policy=42 accuracy accuracy=0.4199
# For batch 81
# best_policy=72 accuracy accuracy=0.4512
# For batch 82
# best_policy=19 accuracy accuracy=0.4023
# For batch 83
# best_policy=15 accuracy accuracy=0.4570
# For batch 84
# best_policy=71 accuracy accuracy=0.4688
# For batch 85
# best_policy=21 accuracy accuracy=0.4766
# For batch 86
# best_policy=70 accuracy accuracy=0.4414
# For batch 87
# best_policy=29 accuracy accuracy=0.4043
# For batch 88
# best_policy=34 accuracy accuracy=0.4414
# For batch 89
# best_policy=83 accuracy accuracy=0.3945
# For batch 90
# best_policy=53 accuracy accuracy=0.4375
# For batch 91
# best_policy=37 accuracy accuracy=0.4688
# For batch 92
# best_policy=4 accuracy accuracy=0.4785
# For batch 93
# best_policy=13 accuracy accuracy=0.4492
# For batch 94
# best_policy=7 accuracy accuracy=0.4492
# For batch 95
# best_policy=6 accuracy accuracy=0.3965
# For batch 96
# best_policy=45 accuracy accuracy=0.4531
# For batch 97
# best_policy=18 accuracy accuracy=0.4258
# For batch 98
# best_policy=32 accuracy accuracy=0.4551
# For batch 99
# best_policy=92 accuracy accuracy=0.4668
# For batch 100
# best_policy=7 accuracy accuracy=0.4375
# For batch 101
# best_policy=19 accuracy accuracy=0.4492
# For batch 102
# best_policy=0 accuracy accuracy=0.4277
# For batch 103
# best_policy=54 accuracy accuracy=0.4609
# For batch 104
# best_policy=93 accuracy accuracy=0.4668
# For batch 105
# best_policy=70 accuracy accuracy=0.4531
# For batch 106
# best_policy=20 accuracy accuracy=0.4590
# For batch 107
# best_policy=0 accuracy accuracy=0.4434
# For batch 108
# best_policy=12 accuracy accuracy=0.4785
# For batch 109
# best_policy=0 accuracy accuracy=0.4727
# For batch 110
# best_policy=27 accuracy accuracy=0.4570
# For batch 111
# best_policy=42 accuracy accuracy=0.4414
# For batch 112
# best_policy=30 accuracy accuracy=0.4688
# For batch 113
# best_policy=38 accuracy accuracy=0.4746
# For batch 114
# best_policy=3 accuracy accuracy=0.4902
# For batch 115
# best_policy=25 accuracy accuracy=0.4570
# For batch 116
# best_policy=24 accuracy accuracy=0.4668
# For batch 117
# best_policy=68 accuracy accuracy=0.3750
# Validation accuracy: 0.45

# %%
import jax.numpy as jnp
# from matplotlib.pyplot import matshow
# import matplotlib.pyplt as plt


train_dataset, test_dataset = get_mnsit_dataloaders(batch_size=512)
# initialize network
params = init(in_features=28*28, hidden_dim=100, out_features=10)

mean = 0
std = 0.1

for epoch in range(10):
    print(f"{epoch=}")
    
    for param in reversed(params.keys()):
        print(f"{param=}")
        
        mean = 0 if epoch == 0 else params[param]["w"]
        std = 0.1 #if epoch == 0 else 
        
        for step, (imgs, labs) in enumerate(train_dataset):
            imgs, labs = jnp.array(imgs), jnp.array(labs)
            
            # explore
            num_policies = 100
            shape_pars = (num_policies,) + params[param]["w"].shape
            
            params[param]["w"] = std * jax.random.normal(jax.random.key(0), shape=shape_pars) + mean
            params[param]["b"] = std * jax.random.normal(jax.random.key(0), shape=shape_pars) + mean
            
            # predict
            outputs = forward(params, imgs)
            
            # evaluate
            policy_returns = policy_evaluation(outputs, labs)
            print(params[param]["w"][best_policy].shape)
            mean = params[param]["w"][best_policy]
            
            best_policy = jnp.argmax(policy_returns, axis=-1)
            accuracy = jnp.max(policy_returns) / imgs.shape[0]
            
            print(f"For batch {step}")
            print(f"{best_policy=:,d} accuracy {accuracy=:.4f}")
            
            params[param]["w"] = params[param]["w"][best_policy]
            # params[param]["b"] = params[param]["b"][best_policy]
            
            # accuracy = jnp.max(policy_returns) / imgs.shape[0]
            
            # print(f"For batch {step}")
            # print(f"{best_policy=:,d} accuracy {accuracy=:.4f}")
# Out:
# Array([16,  9, 13, 10, 10, 21, 15, 12, 13, 15], dtype=int32)

# %%
class PolicySampler:
    def __init__(self, shape):
        self.shape = shape

    def normal_sample(self, seed, mean, std):
        return std * jax.random.normal(jax.random.key(seed), shape=self.shape) + mean
    
    def uniform_sample(self, seed, min, max):
        return jax.random.uniform(jax.random.key(seed), shape=self.shape, minval=min, maxval=max)
